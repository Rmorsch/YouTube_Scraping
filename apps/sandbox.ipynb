# %%
import pandas as pd

# Create a single Timestamp
ts = pd.to_datetime('2023-01-01').dt.date
print(ts)

# Convert a list to a DatetimeIndex
date_list = ['2023-01-01', '2023-01-02', '2023-01-03']
dt_index = pd.to_datetime(date_list).dt.date
print(dt_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 # Create a single Timestamp
# ----> 4 ts = pd.to_datetime('2023-01-01').dt.date
#       5 print(ts)
#       7 # Convert a list to a DatetimeIndex
#
# AttributeError: 'Timestamp' object has no attribute 'dt'
